# %%
# %matplotlib inline
import pyspark
import pandas as pd
import math
import matplotlib.pyplot as plt
import seaborn as sns
import calendar
import operator
from pyspark.ml.feature import OneHotEncoder, StringIndexer, Normalizer
from pyspark.ml.pipeline import Transformer
from pyspark.ml.param.shared import HasInputCol, HasOutputCol, Param
from pyspark import keyword_only
from pyspark.ml import Pipeline
from pyspark.sql import Row
from pyspark.sql import SQLContext

# %%
sc = pyspark.SparkContext(master='local[*]')
sqlContext = SQLContext(sc)
# Out:
# ValueErrorTraceback (most recent call last)
# <ipython-input-79-935071614592> in <module>()
# ----> 1 sc = pyspark.SparkContext(master='local[*]')
#       2 sqlContext = SQLContext(sc)
#
# /usr/local/spark/python/pyspark/context.py in __init__(self, master, appName, sparkHome, pyFiles, environment, batchSize, serializer, conf, gateway, jsc, profiler_cls)
#     113         """
#     114         self._callsite = first_spark_call() or CallSite(None, None, None)
# --> 115         SparkContext._ensure_initialized(self, gateway=gateway, conf=conf)
#     116         try:
#     117             self._do_init(master, appName, sparkHome, pyFiles, environment, batchSize, serializer,
#
# /usr/local/spark/python/pyspark/context.py in _ensure_initialized(cls, instance, gateway, conf)
#     270                         " created by %s at %s:%s "
#     271                         % (currentAppName, currentMaster,
# --> 272                             callsite.function, callsite.file, callsite.linenum))
#     273                 else:
#     274                     SparkContext._active_spark_context = instance
#
# ValueError: Cannot run multiple SparkContexts at once; existing SparkContext(app=pyspark-shell, master=local[*]) created by __init__ at <ipython-input-4-935071614592>:1

# %%
pd.set_option('display.max_columns', 500)

# %%
shelter_pd = pd.read_csv('train.csv')
shelter_test = pd.read_csv('test.csv')

# %%
shelter_pd
# Out:
#       AnimalID        Name             DateTime      OutcomeType  \
# 0      A671945     Hambone  2014-02-12 18:22:00  Return_to_owner
# 1      A656520       Emily  2013-10-13 12:44:00       Euthanasia
# 2      A686464      Pearce  2015-01-31 12:28:00         Adoption
# 3      A683430         NaN  2014-07-11 19:09:00         Transfer
# 4      A667013         NaN  2013-11-15 12:52:00         Transfer
# 5      A677334        Elsa  2014-04-25 13:04:00         Transfer
# 6      A699218       Jimmy  2015-03-28 13:11:00         Transfer
# 7      A701489         NaN  2015-04-30 17:02:00         Transfer
# 8      A671784        Lucy  2014-02-04 17:17:00         Adoption
# 9      A677747         NaN  2014-05-03 07:48:00         Adoption
# 10     A668402         NaN  2013-12-05 15:50:00         Transfer
# 11     A666320         NaN  2013-11-04 14:48:00         Adoption
# 12     A684601      Rocket  2016-02-03 11:27:00         Adoption
# 13     A704702     Scooter  2015-06-08 16:30:00  Return_to_owner
# 14     A688584     Preston  2015-11-25 15:00:00  Return_to_owner
# 15     A678825      Oliver  2014-07-12 12:10:00         Adoption
# 16     A678050         NaN  2014-05-03 16:15:00         Transfer
# 17     A680028         NaN  2014-06-07 12:54:00         Transfer
# 18     A679010     Chrissy  2014-05-17 11:32:00         Transfer
# 19     A684787        Kuma  2014-07-30 17:34:00  Return_to_owner
# 20     A670658      Anders  2014-01-19 15:03:00         Transfer
# 21     A708812    Munchkin  2015-09-18 15:19:00         Transfer
# 22     A705262     Jamaica  2015-08-15 14:22:00         Adoption
# 23     A665781     Quattro  2013-10-28 16:32:00         Adoption
# 24     A676333     Trigger  2014-04-09 17:44:00  Return_to_owner
# 25     A712750       Olive  2015-10-03 15:44:00         Transfer
# 26     A718832         Nia  2016-01-15 17:31:00         Adoption
# 27     A698777       Chloe  2015-03-25 18:50:00         Adoption
# 28     A715348     Cymbale  2015-11-21 13:01:00         Adoption
# 29     A708666         Jax  2015-07-30 14:30:00  Return_to_owner
# ...        ...         ...                  ...              ...
# 26699  A676460       Mario  2014-04-21 14:01:00       Euthanasia
# 26700  A704999        Lion  2015-06-15 19:28:00  Return_to_owner
# 26701  A678842        Ella  2014-06-15 17:41:00         Transfer
# 26702  A713637         NaN  2015-10-11 09:42:00             Died
# 26703  A716670      Mowmow  2015-12-04 12:22:00         Transfer
# 26704  A716223       Alice  2015-11-17 17:17:00         Transfer
# 26705  A662498       Grace  2013-10-19 15:34:00         Transfer
# 26706  A689942        Zoey  2014-10-19 13:29:00         Adoption
# 26707  A682690         NaN  2014-07-01 17:06:00       Euthanasia
# 26708  A666920      Herbie  2013-11-13 17:32:00         Transfer
# 26709  A714386         NaN  2015-10-24 00:00:00         Adoption
# 26710  A692622      Bonnie  2014-11-24 17:21:00         Transfer
# 26711  A666284       Sonja  2013-10-30 18:32:00         Transfer
# 26712  A535277      Merlin  2015-04-20 16:04:00  Return_to_owner
# 26713  A671169         NaN  2014-01-20 17:37:00       Euthanasia
# 26714  A679031        Pete  2014-05-31 16:11:00         Adoption
# 26715  A708833        Luna  2015-08-05 17:03:00         Adoption
# 26716  A697158         Max  2015-05-02 21:04:00         Adoption
# 26717  A519949       Bella  2014-06-30 17:34:00  Return_to_owner
# 26718  A701044         NaN  2015-04-28 14:26:00         Adoption
# 26719  A707871         NaN  2015-07-20 09:00:00         Transfer
# 26720  A704405     Brownie  2015-07-18 14:08:00         Adoption
# 26721  A662019  Green Bean  2014-07-17 09:43:00         Adoption
# 26722  A687056         NaN  2014-08-31 09:00:00         Transfer
# 26723  A716997        Zeus  2016-01-29 18:52:00         Adoption
# 26724  A702446         NaN  2015-05-14 11:56:00         Transfer
# 26725  A718934         NaN  2016-01-20 18:59:00         Transfer
# 26726  A698128        Zeus  2015-03-09 13:33:00         Adoption
# 26727  A677478         NaN  2014-04-27 12:22:00         Transfer
# 26728  A706629         NaN  2015-07-02 09:00:00         Transfer
#
#       OutcomeSubtype AnimalType SexuponOutcome AgeuponOutcome  \
# 0                NaN        Dog  Neutered Male         1 year
# 1          Suffering        Cat  Spayed Female         1 year
# 2             Foster        Dog  Neutered Male        2 years
# 3            Partner        Cat    Intact Male        3 weeks
# 4            Partner        Dog  Neutered Male        2 years
# 5            Partner        Dog  Intact Female        1 month
# 6            Partner        Cat    Intact Male        3 weeks
# 7            Partner        Cat        Unknown        3 weeks
# 8                NaN        Dog  Spayed Female       5 months
# 9            Offsite        Dog  Spayed Female         1 year
# 10              SCRP        Cat        Unknown        2 years
# 11               NaN        Dog  Spayed Female        2 years
# 12            Foster        Dog  Neutered Male        4 years
# 13               NaN        Dog  Neutered Male        2 years
# 14               NaN        Dog  Neutered Male         1 year
# 15            Foster        Cat  Neutered Male       3 months
# 16           Partner        Cat    Intact Male        3 weeks
# 17           Partner        Dog  Intact Female        2 weeks
# 18           Partner        Cat  Intact Female        2 years
# 19               NaN        Dog  Neutered Male         1 year
# 20           Partner        Dog    Intact Male       2 months
# 21           Partner        Cat  Spayed Female         1 year
# 22               NaN        Dog  Spayed Female        2 years
# 23               NaN        Dog  Neutered Male      10 months
# 24               NaN        Dog  Neutered Male       2 months
# 25           Partner        Cat  Intact Female        1 month
# 26               NaN        Dog  Spayed Female       6 months
# 27               NaN        Dog  Spayed Female        5 years
# 28               NaN        Cat  Spayed Female       2 months
# 29               NaN        Cat  Neutered Male        7 years
# ...              ...        ...            ...            ...
# 26699       Behavior        Dog  Neutered Male        2 years
# 26700            NaN        Dog    Intact Male      10 months
# 26701        Partner        Dog  Intact Female      11 months
# 26702      In Kennel        Cat  Spayed Female        2 years
# 26703        Partner        Cat  Neutered Male        6 years
# 26704        Partner        Cat  Intact Female        4 weeks
# 26705        Partner        Cat  Intact Female       2 months
# 26706            NaN        Cat  Spayed Female       2 months
# 26707      Suffering        Cat        Unknown         1 year
# 26708        Partner        Dog  Neutered Male        2 years
# 26709            NaN        Dog  Spayed Female        1 month
# 26710        Partner        Dog  Intact Female        1 month
# 26711        Partner        Dog  Intact Female         1 year
# 26712            NaN        Dog  Neutered Male       12 years
# 26713      Suffering        Cat  Intact Female       18 years
# 26714            NaN        Cat  Spayed Female       2 months
# 26715            NaN        Dog  Spayed Female       2 months
# 26716        Offsite        Dog  Neutered Male       2 months
# 26717            NaN        Dog  Spayed Female        9 years
# 26718            NaN        Dog  Neutered Male       2 months
# 26719           SCRP        Cat        Unknown        2 years
# 26720            NaN        Cat  Spayed Female       2 months
# 26721         Foster        Cat  Spayed Female        5 years
# 26722           SCRP        Cat    Intact Male       5 months
# 26723            NaN        Dog  Neutered Male        6 years
# 26724        Partner        Cat    Intact Male        1 month
# 26725           SCRP        Cat  Spayed Female       3 months
# 26726            NaN        Dog  Neutered Male        4 years
# 26727        Partner        Cat    Intact Male        4 weeks
# 26728           SCRP        Cat    Intact Male         1 year
#
#                                        Breed                Color
# 0                      Shetland Sheepdog Mix          Brown/White
# 1                     Domestic Shorthair Mix          Cream Tabby
# 2                               Pit Bull Mix           Blue/White
# 3                     Domestic Shorthair Mix           Blue Cream
# 4                Lhasa Apso/Miniature Poodle                  Tan
# 5          Cairn Terrier/Chihuahua Shorthair            Black/Tan
# 6                     Domestic Shorthair Mix           Blue Tabby
# 7                     Domestic Shorthair Mix          Brown Tabby
# 8              American Pit Bull Terrier Mix            Red/White
# 9                              Cairn Terrier                White
# 10                    Domestic Shorthair Mix                Black
# 11                   Miniature Schnauzer Mix               Silver
# 12                              Pit Bull Mix                Brown
# 13                     Yorkshire Terrier Mix            Black/Red
# 14                        Great Pyrenees Mix          White/Cream
# 15                    Domestic Shorthair Mix   Orange Tabby/White
# 16                    Domestic Shorthair Mix          Brown Tabby
# 17                              Pit Bull Mix          Brown/White
# 18                                Angora Mix                White
# 19                   Flat Coat Retriever Mix                Black
# 20                     Queensland Heeler Mix          Black/White
# 21                    Domestic Shorthair Mix                White
# 22                         Plott Hound/Boxer  Brown Brindle/White
# 23                       German Shepherd Mix          Brown/White
# 24                       German Shepherd Mix          Black/Brown
# 25                    Domestic Shorthair Mix         Orange Tabby
# 26        American Staffordshire Terrier Mix      Chocolate/White
# 27                   Chihuahua Shorthair Mix            White/Tan
# 28                    Domestic Shorthair Mix    Cream Tabby/White
# 29                          Russian Blue Mix                 Blue
# ...                                      ...                  ...
# 26699          American Pit Bull Terrier Mix          White/Black
# 26700         Great Pyrenees/Anatol Shepherd            Tan/Cream
# 26701               Jack Russell Terrier Mix          White/Black
# 26702                            Siamese Mix           Lynx Point
# 26703                  Domestic Longhair Mix           Seal Point
# 26704                 Domestic Shorthair Mix          White/Black
# 26705                 Domestic Shorthair Mix               Tortie
# 26706                 Domestic Shorthair Mix                Black
# 26707                 Domestic Shorthair Mix          Brown Tabby
# 26708                Chihuahua Shorthair Mix          White/Brown
# 26709                Chihuahua Shorthair Mix           Sable/Buff
# 26710  Chihuahua Shorthair/Yorkshire Terrier          Brown/Black
# 26711               Cocker Spaniel/Dachshund                 Buff
# 26712                            Rat Terrier        Chocolate/Tan
# 26713                  Domestic Longhair Mix               Tortie
# 26714                 Domestic Shorthair Mix         Orange Tabby
# 26715                            Pointer Mix          Black/White
# 26716                       Newfoundland Mix          White/Black
# 26717                        Bullmastiff Mix                Black
# 26718         Siberian Husky/German Shepherd       Black/Tricolor
# 26719                 Domestic Shorthair Mix    Brown Tabby/White
# 26720                 Domestic Shorthair Mix          Brown Tabby
# 26721                 Domestic Shorthair Mix                Black
# 26722                 Domestic Shorthair Mix         Orange Tabby
# 26723                      Staffordshire Mix           Blue/White
# 26724                 Domestic Shorthair Mix    Brown Tabby/White
# 26725                 Domestic Shorthair Mix          Brown Tabby
# 26726                Old English Bulldog Mix            White/Tan
# 26727                 Domestic Shorthair Mix                Black
# 26728                 Domestic Shorthair Mix    Brown Tabby/White
#
# [26729 rows x 10 columns]

# %% [markdown]
# ## Análisis de datos

# %% [markdown]
# En primer lugar es necesario analizar los datos. Por ello, se considera apropiado realizar el Data Quality Report.

# %%
shelter_pd.describe(include = "all")
# Out:
#        AnimalID   Name             DateTime OutcomeType OutcomeSubtype  \
# count     26729  19038                26729       26729          13117
# unique    26729   6374                22918           5             16
# top     A705677    Max  2015-08-11 00:00:00    Adoption        Partner
# freq          1    136                   19       10769           7816
#
#        AnimalType SexuponOutcome AgeuponOutcome                   Breed  \
# count       26729          26728          26711                   26729
# unique          2              5             44                    1380
# top           Dog  Neutered Male         1 year  Domestic Shorthair Mix
# freq        15595           9779           3969                    8810
#
#               Color
# count         26729
# unique          366
# top     Black/White
# freq           2824

# %% [markdown]
# El Data Quality Report nos da un análisis de los datos. Tenemos 26729 filas en el dataset y se puede ver que hay un missing value en la columna SexuponOutcome (<1%), 18 en AgeuponOutcome (<1%), 7691 en Name (~28.7%) y 13612 en OutcomeType(~50.9%).
#
# Como vamos a manejar el problema de los missing values?
#
# - En el caso de SexuponOutcome, podemos simplemente borrar las filas porque no va a afectar nuestro modelo de predicciones.
# - En el caso de AgeuponOutcome, vamos a borrar las filas también porque son muy pocos datos (<1%).
# - En el caso de Name, no nos importa porque no vamos a usar esa columna en nuestro modelo. (El nombre no influye el Outcome del animal..)
# - En el caso de OutcomeSubtype, tenemos muchos missing value porque por algunos valores de OutcomeType, como por ejemplo <i>Return_to_owner</i>, no hacía falta poner más información.
#
# Que tipo de transformaciones vamos a aplicar sobre los datos para que se pueda usar para crear un modelo de predicción?
# - Name: Borramos la columna porque no nos interesa en nuestras predicciones.
# - OutcomeType: Es un feature categórica entonces vamos a aplicar el StringIndexer para que lo transforme a feature numérica.
# - OutcomeSubtype: Borramos la columna porque no nos interesa en nuestras predicciones.
# - AnimalType: Es un feature categórica entonces vamos a aplicar el StringIndexer para que lo transforme a feature numérica.
# - SexuponOutcome: Es un feature categórica entonces vamos a aplicar el StringIndexer para que lo transforme a feature numérica.
# - AgeuponOutcome: Vamos a convertir cada edad en semana para que todos los datos tengan la misma MEDIDA??
# - Breed: Es un feature categórica entonces vamos a aplicar el StringIndexer para que lo transforme a feature numérica.
# - Color: Es un feature categórica entonces vamos a aplicar el StringIndexer para que lo transforme a feature numérica.
#
# Ahora vamos a limpiar los datos y transformar cada feature categórica a numérica para que se pueda usar para crear un modelo de predicción.

# %% [markdown]
# ## Limpiando la información

# %% [markdown]
# ### <i>Name</i>

# %% [markdown]
# En primera instancia se analizará el atributo <i>Name</i>. Cada valor será reemplazado por un 1 en caso de que éste exista, y 0 en caso contrario (missing value). Contando con cierto conocimiento del dominio, se supone que el nombre del animal no debería influenciar su destino. Sin embargo, un indicador de presencia/ausencia de dicho valor, puede indicar de dónde provino el animal. Por ejemplo, si el perro fue entregado por una familia, probablemente tenga un nombre. Si, en cambio, provino de la calle, puede que el nombre no se sepa. La forma en la que llega el animal al refugio, puede llegar a influenciar su destino; y éste es el motivo por el cuál se decide incluir este indicador.

# %%
from pyspark.sql.functions import UserDefinedFunction
from pyspark.sql.types import IntegerType, LongType, BooleanType, StringType


class NameTransformer(Transformer, HasInputCol, HasOutputCol): 
    # Does binning using the module of the division
    @keyword_only
    def __init__(self, inputCol=None, outputCol=None):
        super(NameTransformer, self).__init__()
        kwargs = self.__init__._input_kwargs
        self.setParams(**kwargs)
        
    @keyword_only 
    def setParams(self, inputCol=None, outputCol=None):
        kwargs = self.setParams._input_kwargs
        return self._set(**kwargs)
        
    def _transform(self, dataset):
        in_col = dataset[self.getInputCol()]
        out_col = self.getOutputCol()
        udf = UserDefinedFunction(lambda x: boolean_func(x), StringType())
        return dataset.withColumn(out_col, udf(in_col))

def boolean_func(in_value):
    if (in_value):
        if in_value.lower() == 'nan':
            return 'False'
        else:
            return 'True'
    else:
        return 'False'

# %% [markdown]
# ### <i>DateTime</i>

# %% [markdown]
# Para lidiar con las fechas, se considera apropiado separarla en tres features diferentes: día, mes, año. De esta manera, una feature continua como <i>DateTime</i> se convierte en tres categóricas. Se ignora la hora porque no se considera relevante para el caso de estudio.

# %%
class YearExtractor(Transformer, HasInputCol, HasOutputCol): 
    # Creates a column year
    @keyword_only
    def __init__(self, inputCol=None, outputCol=None):
        super(YearExtractor, self).__init__()
        kwargs = self.__init__._input_kwargs
        self.setParams(**kwargs)
        
    @keyword_only 
    def setParams(self, inputCol=None, outputCol=None):
        kwargs = self.setParams._input_kwargs
        return self._set(**kwargs)
        
    def _transform(self, dataset):
        in_col = dataset[self.getInputCol()]
        out_col = self.getOutputCol()
        udf = UserDefinedFunction(lambda x: isolateYear(x), StringType())
        return dataset.withColumn(out_col, udf(in_col))

class MonthExtractor(Transformer, HasInputCol, HasOutputCol): 
    # Creates a column month
    @keyword_only
    def __init__(self, inputCol=None, outputCol=None):
        super(MonthExtractor, self).__init__()
        kwargs = self.__init__._input_kwargs
        self.setParams(**kwargs)
        
    @keyword_only 
    def setParams(self, inputCol=None, outputCol=None):
        kwargs = self.setParams._input_kwargs
        return self._set(**kwargs)
        
    def _transform(self, dataset):
        in_col = dataset[self.getInputCol()]
        out_col = self.getOutputCol()
        udf = UserDefinedFunction(lambda x: isolateMonth(x), StringType())
        return dataset.withColumn(out_col, udf(in_col))

class DayExtractor(Transformer, HasInputCol, HasOutputCol): 
    # Creates a column day
    @keyword_only
    def __init__(self, inputCol=None, outputCol=None):
        super(DayExtractor, self).__init__()
        kwargs = self.__init__._input_kwargs
        self.setParams(**kwargs)
        
    @keyword_only 
    def setParams(self, inputCol=None, outputCol=None):
        kwargs = self.setParams._input_kwargs
        return self._set(**kwargs)
        
    def _transform(self, dataset):
        in_col = dataset[self.getInputCol()]
        out_col = self.getOutputCol()
        udf = UserDefinedFunction(lambda x: isolateDay(x), StringType())
        return dataset.withColumn(out_col, udf(in_col))

def isolateDay(in_value):
    return in_value.split()[0][8:]

def isolateMonth(in_value):
    month_number = int(in_value.split()[0][5:7])
    return calendar.month_name[month_number]

def isolateYear(in_value):
    return in_value.split()[0][:4]

# %% [markdown]
# ### AgeuponOutcome

# %% [markdown]
# Con respecto a la edad de los animales, se considero apropiado separarla en features distintas: young, young_adult, adult, old_adult y old. Para realizar esto se va utilizar Binning, pero se utilizara un binning informal el cual seapara las categorias en funcion de la cantidad de años del animal, ya que es de suma importancia para la prediccion que la edad del animal corresponda a su categoria especifica.

# %%
class AgeuponOutcomeTransformer(Transformer, HasInputCol, HasOutputCol): 
    # Does binning using the module of the division
    @keyword_only
    def __init__(self, inputCol=None, outputCol=None):
        super(AgeuponOutcomeTransformer, self).__init__()
        kwargs = self.__init__._input_kwargs
        self.setParams(**kwargs)
        
    @keyword_only 
    def setParams(self, inputCol=None, outputCol=None):
        kwargs = self.setParams._input_kwargs
        return self._set(**kwargs)
        
    def _transform(self, dataset):
        in_col = dataset[self.getInputCol()]
        out_col = self.getOutputCol()
        udf = UserDefinedFunction(lambda x: binner_func(x), StringType())
        return dataset.withColumn(out_col, udf(in_col))

def binner_func(in_value):
    age_in_days = 0
    splited_value = in_value.split(' ')        
    if (splited_value[1] == 'years' or splited_value[1] == 'year'):
        age_in_days = int(splited_value[0])*365
    elif(splited_value[1] == 'months' or splited_value[1] == 'month'):
        age_in_days = int(splited_value[0])*30
    elif(splited_value[1] == 'weeks' or splited_value[1] == 'week'):
        age_in_days = int(splited_value[0])*7  
    elif(splited_value[1] == 'days' or splited_value[1] == 'day'):
        age_in_days = int(splited_value[0])
        
    if (age_in_days > 0 and age_in_days <= 365):
        return 'young'
    elif (age_in_days > 365 and age_in_days <= 365*3):
        return 'young_adult'
    elif (age_in_days > 365*3 and age_in_days <= 365*7):
        return 'adult'
    elif (age_in_days > 365*7 and age_in_days <= 365*10):
        return 'old_adult'
    elif (age_in_days > 365*10):
         return 'old'

# %% [markdown]
# ### <i>OutcomeType</i>

# %% [markdown]
# Este es el target feature. Por lo tanto, es necesario verificar que no hay missing values y, en caso de haberlos, se deben eliminar dichas filas ya que no aportan ningún tipo de información. Sin embargo, como se puede apreciar del Data Quality Report detallado anteriormente, no hay missing values. <br>
# Analizo que no haya ningún nivel dentro de la feature con nombre <i>unknown</i> o algo similar.

# %%
pd.DataFrame(shelter_pd.OutcomeType.value_counts()).plot(kind='bar')

# %% [markdown]
# Efectivamente, todas las filas parecen contener información de utilidad, por lo que no se necesita realizar limpieza alguna.

# %% [markdown]
# ### <i>Animal type</i>

# %% [markdown]
# Se grafican las frecuencias para cada uno de los niveles del feature para detectar alguna anomalía en la información pero, como se puede ver, no la hay.

# %%
pd.DataFrame(shelter_pd.AnimalType.value_counts()).plot(kind='bar')

# %% [markdown]
# ### <i>SexuponOutcome</i>

# %% [markdown]
# Como podemos ver en el Data Quality Report, hay un missing value. Sin embargo, se considera apropiado investigar qué niveles toma esta feature a partir de un gráfico de histograma.

# %%
pd.DataFrame(shelter_pd.SexuponOutcome.value_counts()).plot(kind='bar')

# %% [markdown]
# Tanto el missing value, como los calificados como <i>unknown</i>, se les imputará un valor (ya que totalizan menos del 30% de los datos). Para ello necesito determinadas funciones genéricas como obtener la moda, contar la cantidad de veces que un valor aparece en una columna y demás.

# %%
import operator

def valueCountPandas(DF, column, value): 
    '''
        Function that counts the number of occurrences of a value in a given column
        First parameter is a pandas DataFrame
        Second parameter is the name of a column (String)
        Third parameter is the value that needs to be counted (String)
    '''
    count = 0
    columnIndex = DF.columns.get_loc(column)
    for (index, row) in DF.iterrows():
        if row[columnIndex] == value:
            count += 1
    return count

def valueCount(DF, column, value):
    '''
        Function that counts the number of occurrences of a value in a given column
        First parameter is a Spark DataFrame
        Second parameter is the name of a column (String)
        Third parameter is the value that needs to be counted (String)
    '''
    return DF.rdd.filter(lambda x: x[column] == value).count()

def missingValuesRemover(DF, column):
    '''
        Removes the rows with missing values in the given column
        First parameter is a pandas DataFrame
        Second parameter is the name of the column to be analyzed
    '''
    count = 0
    columnIndex = DF.columns.get_loc(column)
    for (index, row) in DF.iterrows():
        if str(row[columnIndex]).lower().split() == ['nan']:
            DF = DF.drop(index)
            count += 1
    print(str(count) + " row(s) removed")
    return DF

def selectDistinctPandas(DF, column):
    '''
        Selects all distinct value from column
        First parameter is a pandas DataFrame
        Second parameter is the name of the column to select the values from
    '''
    distinctList = []
    columnIndex = DF.columns.get_loc(column)
    for (index, row) in DF.iterrows():
        if row[columnIndex] not in distinctList:
            distinctList.append(row[columnIndex])
    return distinctList

def selectDistinct(DF, column):
    '''
        Selects all distinct value from column
        First parameter is a Spark DataFrame
        Second parameter is the name of the column to select the values from
    '''
    return DF.rdd.map(lambda x: x[column]).distinct().collect()

def getMode(DF, column):
    '''
        Gets mode of a given column in the dataset
        First parameter is a pandas DataFrame
        Second parameter is the name of the column to get the mode from
    '''
    countDict = {}
    selectDistinctList = selectDistinct(DF, column)
    for i in selectDistinctList:
        countDict[i] = valueCount(DF, column, i)
    return sorted(countDict.items(), key=operator.itemgetter(1))[-1][0]

# %%
class FillMissingValues(Transformer, HasInputCol, HasOutputCol): 
    # Creates a column day
    @keyword_only
    def __init__(self, inputCol=None, outputCol=None):
        super(FillMissingValues, self).__init__()
        kwargs = self.__init__._input_kwargs
        self.setParams(**kwargs)
        
    @keyword_only 
    def setParams(self, inputCol=None, outputCol=None):
        kwargs = self.setParams._input_kwargs
        return self._set(**kwargs)
        
    def _transform(self, dataset):
        in_col = dataset[self.getInputCol()]
        out_col = self.getOutputCol()
        modeAttribute = getMode(shelter_df, self.getInputCol())
        udf = UserDefinedFunction(lambda x: fillMissingValues(x, modeAttribute), StringType())
        return dataset.withColumn(out_col, udf(in_col))
    
def fillMissingValues(input_value, mode):
    if(input_value):
        if (input_value.lower() == 'nan' or input_value.lower() == 'unknown'):
            return mode
        else:
            return input_value
    else:
        return mode

# %% [markdown]
# ### <i>AgeuponOutcome</i>

# %%
pd.DataFrame(shelter_pd['AgeuponOutcome'].value_counts()).plot(kind='bar')

# %% [markdown]
# ### <i>Breed</i>

# %% [markdown]
# ### <i>Color</i>

# %% [markdown]
# Se hace la limpieza de datos con la ayuda de <i>Pipelines</i>, y se obtiene un DataFrame de Spark.

# %%
Name_transformer = NameTransformer(inputCol='Name', outputCol='Name')
DateTime_YearExtractor = YearExtractor(inputCol='DateTime', outputCol='Year')
DateTime_MonthExtractor = MonthExtractor(inputCol='DateTime', outputCol='Month')
DateTime_DayExtractor = DayExtractor(inputCol='DateTime', outputCol='Day')
SexuponOutcome_transformer = FillMissingValues(inputCol='SexuponOutcome', outputCol='SexuponOutcome')
AgeuponOutcome_transformer = FillMissingValues(inputCol='AgeuponOutcome', outputCol='AgeuponOutcome')
AgeuponOutcome_binner_transformer = AgeuponOutcomeTransformer(inputCol='AgeuponOutcome', outputCol='AgeuponOutcome')

# %%
shelter_pd = shelter_pd[['Name', 'DateTime', 'OutcomeType', 'AnimalType', 'SexuponOutcome', 'AgeuponOutcome', 'Breed', 'Color']].astype(str)
shelter_df = sqlContext.createDataFrame(shelter_pd)
pipeline = Pipeline(stages=[Name_transformer, AgeuponOutcome_transformer, AgeuponOutcome_binner_transformer, SexuponOutcome_transformer, DateTime_YearExtractor, DateTime_DayExtractor, DateTime_MonthExtractor ])
model = pipeline.fit(shelter_df)
shelter_cleaned_df = model.transform(shelter_df)

# %%
#Drop the columns that are not needed
shelter_cleaned_df.toPandas()
# Out:
#         Name             DateTime      OutcomeType AnimalType SexuponOutcome  \
# 0       True  2014-02-12 18:22:00  Return_to_owner        Dog  Neutered Male
# 1       True  2013-10-13 12:44:00       Euthanasia        Cat  Spayed Female
# 2       True  2015-01-31 12:28:00         Adoption        Dog  Neutered Male
# 3      False  2014-07-11 19:09:00         Transfer        Cat    Intact Male
# 4      False  2013-11-15 12:52:00         Transfer        Dog  Neutered Male
# 5       True  2014-04-25 13:04:00         Transfer        Dog  Intact Female
# 6       True  2015-03-28 13:11:00         Transfer        Cat    Intact Male
# 7      False  2015-04-30 17:02:00         Transfer        Cat  Neutered Male
# 8       True  2014-02-04 17:17:00         Adoption        Dog  Spayed Female
# 9      False  2014-05-03 07:48:00         Adoption        Dog  Spayed Female
# 10     False  2013-12-05 15:50:00         Transfer        Cat  Neutered Male
# 11     False  2013-11-04 14:48:00         Adoption        Dog  Spayed Female
# 12      True  2016-02-03 11:27:00         Adoption        Dog  Neutered Male
# 13      True  2015-06-08 16:30:00  Return_to_owner        Dog  Neutered Male
# 14      True  2015-11-25 15:00:00  Return_to_owner        Dog  Neutered Male
# 15      True  2014-07-12 12:10:00         Adoption        Cat  Neutered Male
# 16     False  2014-05-03 16:15:00         Transfer        Cat    Intact Male
# 17     False  2014-06-07 12:54:00         Transfer        Dog  Intact Female
# 18      True  2014-05-17 11:32:00         Transfer        Cat  Intact Female
# 19      True  2014-07-30 17:34:00  Return_to_owner        Dog  Neutered Male
# 20      True  2014-01-19 15:03:00         Transfer        Dog    Intact Male
# 21      True  2015-09-18 15:19:00         Transfer        Cat  Spayed Female
# 22      True  2015-08-15 14:22:00         Adoption        Dog  Spayed Female
# 23      True  2013-10-28 16:32:00         Adoption        Dog  Neutered Male
# 24      True  2014-04-09 17:44:00  Return_to_owner        Dog  Neutered Male
# 25      True  2015-10-03 15:44:00         Transfer        Cat  Intact Female
# 26      True  2016-01-15 17:31:00         Adoption        Dog  Spayed Female
# 27      True  2015-03-25 18:50:00         Adoption        Dog  Spayed Female
# 28      True  2015-11-21 13:01:00         Adoption        Cat  Spayed Female
# 29      True  2015-07-30 14:30:00  Return_to_owner        Cat  Neutered Male
# ...      ...                  ...              ...        ...            ...
# 26699   True  2014-04-21 14:01:00       Euthanasia        Dog  Neutered Male
# 26700   True  2015-06-15 19:28:00  Return_to_owner        Dog    Intact Male
# 26701   True  2014-06-15 17:41:00         Transfer        Dog  Intact Female
# 26702  False  2015-10-11 09:42:00             Died        Cat  Spayed Female
# 26703   True  2015-12-04 12:22:00         Transfer        Cat  Neutered Male
# 26704   True  2015-11-17 17:17:00         Transfer        Cat  Intact Female
# 26705   True  2013-10-19 15:34:00         Transfer        Cat  Intact Female
# 26706   True  2014-10-19 13:29:00         Adoption        Cat  Spayed Female
# 26707  False  2014-07-01 17:06:00       Euthanasia        Cat  Neutered Male
# 26723           Blue/White  2016  29    January
# 26724    Brown Tabby/White  2015  14        May
# 26725          Brown Tabby  2016  20    January
# 26726            White/Tan  2015  09      March
# 26727                Black  2014  27      April
# 26728    Brown Tabby/White  2015  02       July
#
# [26729 rows x 11 columns]

# %%
(training, testing) = shelter_cleaned_df.randomSplit([0.8, 0.2])

shelter = shelter_cleaned_df.toPandas()
shelter = shelter.drop(['DateTime'], 1)
cols = ['Name', 'AnimalType', 'SexuponOutcome', 'AgeuponOutcome', 'Breed', 'Color', 'Year', 'Day', 'Month', 'OutcomeType']
shelter = shelter[cols]


training = training.toPandas()
training = training.drop(['DateTime'], 1)
cols = ['Name', 'AnimalType', 'SexuponOutcome', 'AgeuponOutcome', 'Breed', 'Color', 'Year', 'Day', 'Month', 'OutcomeType']
training = training[cols]


testing = testing.toPandas()
testing = testing.drop(['DateTime'], 1)
cols = ['Name', 'AnimalType', 'SexuponOutcome', 'AgeuponOutcome', 'Breed', 'Color', 'Year', 'Day', 'Month', 'OutcomeType']
testing = testing[cols]

# %% [markdown]
# ## Naive Bayes

# %% [markdown]
# Uno de los modelos que se utilizara para la prediccion sobre un nuevo animal, va a ser Naive Bayes. Este modelo ... bla bla bla

# %%
class NaiveBayes:
    def __init__(self, dataframe, target_feature):       
        self.dataframe = dataframe
        self.target_feature  = target_feature
    
    def naive_bayes_probabilities(self):        
        df = self.dataframe.copy()
        df['count'] = [1] * len(df.index)
        target_feature = self.target_feature
        aux_probabilities = []
        for column in df.columns:
            if column not in [target_feature, 'count']: 
                counts = df.pivot_table(index=target_feature, columns=column, aggfunc=len, margins=True, values='count')
                percent = counts.div(counts.iloc[:,-1], axis=0)
                percent = percent.drop('All', 1)
                aux_probabilities.extend([percent])
        aux_probabilities.extend([df.groupby(self.target_feature).agg({'count':sum}).div(len(df.index))])        
        probabilities = aux_probabilities[0].join(aux_probabilities[1:])
        probabilities = probabilities.fillna(0)
        probabilities = probabilities.drop(probabilities.index[-1])
        self.probabilities = probabilities
        return probabilities
    
    def naive_bayes_smoothed_probabilities(self, k):
        df = self.dataframe.copy()
        df['count'] = [1] * len(df.index)
        target_feature = self.target_feature
        aux_probabilities = []
        for column in df.columns:
            if column not in [target_feature, 'count']: 
                counts = df.pivot_table(index=target_feature, columns=column, aggfunc=len, margins=True, values='count')
                counts = counts.fillna(0)
                categories = list(counts.columns)
                features = list(counts.index)
                del features[-1]
                domain = len(categories) - 1
                percent = self.smooth(features, categories, counts, domain, k)
                percent = percent.drop('All', 1)
                aux_probabilities.extend([percent])
        aux_probabilities.extend([df.groupby(target_feature).agg({'count':sum}).div(len(df.index))])
        probabilities = aux_probabilities[0].join(aux_probabilities[1:])
        probabilities = probabilities.drop(probabilities.index[-1])
        self.probabilities = probabilities
        return probabilities
    
    def predict(self, instance):
        predictions = {}
        outputs = self.dataframe[self.target_feature].unique()
        for output in outputs:
            predictions[output] = self.target_probability(instance,output)
        return predictions
    
    def target_probability(self, instance, target):
        target_count = self.dataframe[(self.dataframe[self.target_feature] == target)].count()[0]
        instance_probabilities = []
        for feature in instance:
            probability = self.probabilities[feature][target]
            instance_probabilities.append(probability)
        multiplication = reduce(lambda x, y: x*y, instance_probabilities)
        multiplication = multiplication * target_count
        count = self.dataframe.count()[0]
        probability = multiplication/float(count)
        return probability
    
    def smooth_probability(self, count_bayes, count_feature, domain, k):
        result = (count_bayes + k) / (count_feature + (k * domain))
        return result
    
    def smooth(self, features, categories, df, domain ,k):
        for i in range(0,len(features)):
            for j in range(0,len(categories)-1):
                count_bayes = df.iloc[i,j]
                count_feature = df.iloc[i,-1]
                smoothed_probability = self.smooth_probability(count_bayes, count_feature, domain, k)
                df.iloc[i,j] = smoothed_probability
        return df
    
    def run(self, dataframe):
        #predictions = self.predict(dataframe)
        def do_prediction(x):
            instance = list(x)
            del instance[-1]
            predictions = self.predict(instance)
            prediction = max(predictions.iteritems(), key=operator.itemgetter(1))[0]
            return prediction
        dataframe['Prediction'] = dataframe.apply(do_prediction, axis=1)
        return dataframe

# %% [markdown]
# En una primera instancia se convierten los dataframes de spark a pandas

# %%
# shelter = shelter_cleaned_df.toPandas()
# shelter = shelter.drop(['DateTime'], 1)
# shelter

# %% [markdown]
# Luego se crea una instancia de la clase NaiveBayes, responsable de generar entrenar el modelo y realizar las predicciones

# %%
NaiveBayes = NaiveBayes(shelter,'OutcomeType')

# %% [markdown]
# Se entrena el modelo, con el dataset utilizando el algoritmo de naive bayes

# %%
#NaiveBayes.naive_bayes_probabilities()

# %% [markdown]
# Se puede observar que en el modelo existen probabilidades iguales a 0 por lo tanto, es posible que algunos valores no se predigan de forma correcta, por lo tanto es necesario utilizar smoothing para resolver este problema. En particular se utilizara Laplace Smoothing con k = 3

# %%
NaiveBayes.naive_bayes_smoothed_probabilities(3)
# Out:
#                     False      True       Cat       Dog  Intact Female  \
# OutcomeType
# Adoption         0.156009  0.843991  0.396752  0.603248       0.019108
# Died             0.605911  0.394089  0.738916  0.261084       0.282297
# Euthanasia       0.524023  0.475977  0.456758  0.543242       0.257817
# Return_to_owner  0.032554  0.967446  0.104967  0.895033       0.063360
# Transfer         0.522698  0.477302  0.584217  0.415783       0.270617
#
#                  Intact Male  Neutered Male  Spayed Female     adult  \
# OutcomeType
# Adoption            0.014934       0.484649       0.481310  0.092637
# Died                0.392344       0.224880       0.100478  0.047393
# Euthanasia          0.306318       0.285897       0.149968  0.171556
# Return_to_owner     0.100042       0.471655       0.364944  0.253697
# Transfer            0.247721       0.307929       0.173733  0.083139
#
#                       old  old_adult     young  young_adult  Abyssinian Mix  \
# OutcomeType
# Adoption         0.012240   0.033661  0.683049     0.178412        0.000335
# Died             0.028436   0.066351  0.729858     0.127962        0.000692
# Euthanasia       0.102679   0.102679  0.355867     0.267219        0.000527
# Return_to_owner  0.073943   0.098105  0.259946     0.314310        0.000336
# Transfer         0.012104   0.029306  0.694840     0.180612        0.000221
#
#                  Affenpinscher Mix  Afghan Hound Mix  Airedale Terrier  \
# OutcomeType
# Adoption                  0.000470          0.000201          0.000201
# Died                      0.000692          0.000692          0.000692
# Euthanasia                0.000527          0.000527          0.000527
# Return_to_owner           0.000560          0.000448          0.000336
# Transfer                  0.000221          0.000221          0.000295
#
#                  Airedale Terrier Mix  Airedale Terrier/Labrador Retriever  \
# OutcomeType
# Adoption                     0.000268                             0.000201
# Died                         0.000692                             0.000692
# Euthanasia                   0.000527                             0.000527
# Return_to_owner              0.000560                             0.000336
# Transfer                     0.000369                             0.000295
#
#                  Airedale Terrier/Miniature Schnauzer     Akita  Akita Mix  \
# OutcomeType
# Adoption                                     0.000268  0.000335   0.000470
# Died                                         0.000692  0.000692   0.000692
# Euthanasia                                   0.000527  0.000702   0.000527
# Return_to_owner                              0.000336  0.000336   0.000896
# Transfer                                     0.000221  0.000221   0.000369
#
#                  Akita/Australian Cattle Dog  Akita/Chow Chow  \
# OutcomeType
# Adoption                            0.000268         0.000268
# Died                                0.000692         0.000692
# Euthanasia                          0.000527         0.000527
# Return_to_owner                     0.000336         0.000336
# Transfer                            0.000221         0.000221
#
#                  Akita/German Shepherd  Akita/Labrador Retriever  \
# OutcomeType
# Adoption                      0.000201                  0.000201
# Died                          0.000692                  0.000692
# Euthanasia                    0.000527                  0.000527
# Return_to_owner               0.000448                  0.000336
# Transfer                      0.000221                  0.000295
#
#                  Akita/Pit Bull  Akita/Siberian Husky  Alaskan Husky  \
# OutcomeType
# Adoption               0.000201              0.000335       0.000268
# Died                   0.000692              0.000692       0.000692
# Euthanasia             0.000702              0.000527       0.000527
# Return_to_owner        0.000336              0.000336       0.000448
# Transfer               0.000221              0.000221       0.000221
#
#                  Alaskan Husky Mix  Alaskan Husky/Australian Shepherd  \
# OutcomeType
# Adoption                  0.000537                           0.000201
# Died                      0.000692                           0.000692
# Euthanasia                0.000527                           0.000527
# Return_to_owner           0.000896                           0.000448
# Transfer                  0.000221                           0.000295
#
#                  Alaskan Husky/Border Collie  Alaskan Husky/German Shepherd  \
# OutcomeType
# Adoption                            0.000268                       0.000201
# Died                                0.000692                       0.000692
# Euthanasia                          0.000527                       0.000527
# Return_to_owner                     0.000336                       0.000336
# Transfer                            0.000221                       0.000295
#
#                  Alaskan Malamute  Alaskan Malamute Mix  \
# OutcomeType
# Adoption                 0.000201              0.000268
# Died                     0.000692              0.000692
# Euthanasia               0.000527              0.000527
# Return_to_owner          0.000448              0.000784
# Transfer                 0.000221              0.000221
#
#                  Alaskan Malamute/Akita  Alaskan Malamute/Australian Kelpie  \
# OutcomeType
# Adoption                       0.000268                            0.000268
# Died                           0.000692                            0.000692
# Euthanasia                     0.000527                            0.000527
# Return_to_owner                0.000336                            0.000336
# Transfer                       0.000221                            0.000221
#
#                  Alaskan Malamute/Border Collie  \
# OutcomeType
# Adoption                               0.000268
# Died                                   0.000692
# Euthanasia                             0.000527
# Return_to_owner                        0.000336
# Transfer                               0.000295
#
#                  Alaskan Malamute/German Shepherd  American Bulldog  \
# OutcomeType
# Adoption                                 0.000201          0.000335
# Died                                     0.000692          0.000692
# Euthanasia                               0.000527          0.000527
# Return_to_owner                          0.000448          0.000784
# Transfer                                 0.000221          0.000221
#
#                  American Bulldog Mix  \
# OutcomeType
# Adoption                     0.002683
# Died                         0.000692
# Euthanasia                   0.002458
# Return_to_owner              0.004257
# Transfer                     0.002138
#
#                  American Bulldog/American Staffordshire Terrier  \
# OutcomeType
# Adoption                                                0.000201
# Died                                                    0.000692
# Euthanasia                                              0.000527
# Return_to_owner                                         0.000336
# Transfer                                                0.000295
#
#                  American Bulldog/Chinese Sharpei  \
# OutcomeType
# Adoption                                 0.000201
# Died                                     0.000692
# Euthanasia                               0.000527
# Return_to_owner                          0.000448
# Transfer                                 0.000221
#
#                  American Bulldog/Great Pyrenees  \
# OutcomeType
# Adoption                                0.000201
# Died                                    0.000692
# Euthanasia                              0.000527
# Return_to_owner                         0.000336
# Transfer                                0.000295
#
#                  American Bulldog/Labrador Retriever  \
# OutcomeType
# Adoption                                    0.000335
# Died                                        0.000692
# Euthanasia                                  0.000527
# Return_to_owner                             0.000336
# Transfer                                    0.000295
#
#                  American Bulldog/Mastiff  American Bulldog/Pit Bull  \
# OutcomeType
# Adoption                         0.000268                   0.000335
# Died                             0.000692                   0.000692
# Euthanasia                       0.000527                   0.000878
# Return_to_owner                  0.000448                   0.000336
# Transfer                         0.000221                   0.000221
#
#                  American Bulldog/Pointer  American Bulldog/Schnauzer Giant  \
# OutcomeType
# Adoption                         0.000201                          0.000268
# Died                             0.000692                          0.000692
# Euthanasia                       0.000527                          0.000527
# Return_to_owner                  0.000448                          0.000336
# Transfer                         0.000295                          0.000221
#
#                  American Eskimo  American Eskimo Mix  \
# OutcomeType
# Adoption                0.000201             0.000402
# Died                    0.000692             0.000692
# Euthanasia              0.000527             0.000878
# Return_to_owner         0.000448             0.000672
# Transfer                0.000295             0.000295
#
#                  American Eskimo/Australian Shepherd  \
# OutcomeType
# Adoption                                    0.000268
# Died                                        0.000692
# Euthanasia                                  0.000527
# Return_to_owner                             0.000336
# Transfer                                    0.000221
#
#                  American Eskimo/Border Collie  American Foxhound  \
# OutcomeType
# Adoption                              0.000335           0.000201
# Died                                  0.000692           0.000692
# Euthanasia                            0.000527           0.000527
# Return_to_owner                       0.000336           0.000448
# Transfer                              0.000221           0.000221
#
#                  American Foxhound Mix  American Foxhound/Labrador Retriever  \
# OutcomeType
# Adoption                      0.000201                              0.000268
# Died                          0.000692                              0.000692
# Euthanasia                    0.000527                              0.000527
# Return_to_owner               0.000560                              0.000336
# Transfer                      0.000221                              0.000221
#
#                  American Foxhound/Pointer  American Pit Bull Terrier  \
# OutcomeType
# Adoption                          0.000268                   0.000201
# Died                              0.000692                   0.000692
# Euthanasia                        0.000527                   0.000702
# Return_to_owner                   0.000336                   0.000560
# Transfer                          0.000221                   0.000369
#
#                  American Pit Bull Terrier Mix  \
# OutcomeType
# Adoption                              0.001945
# Died                                  0.000692
# Euthanasia                            0.001229
# Return_to_owner                       0.002241
# Transfer                              0.001770
#
#                  American Pit Bull Terrier/American Bulldog  \
# OutcomeType
# Adoption                                           0.000201
# Died                                               0.000692
# Euthanasia                                         0.000527
# Return_to_owner                                    0.000448
# Transfer                                           0.000221
#
#                  American Pit Bull Terrier/American Pit Bull Terrier  \
# OutcomeType
# Adoption                                                  0.000201
# Died                                                      0.000692
# Euthanasia                                                0.000527
# Return_to_owner                                           0.000448
# Transfer                                                  0.000221
#
#                  American Pit Bull Terrier/Boxer  \
# OutcomeType
# Adoption                                0.000335
# Died                                    0.000692
# Euthanasia                              0.000527
# Return_to_owner                         0.000336
# Transfer                                0.000221
#
#                  American Pit Bull Terrier/Catahoula  \
# OutcomeType
# Adoption                                    0.000201
# Died                                        0.000692
# Euthanasia                                  0.000527
# Return_to_owner                             0.000448
# Transfer                                    0.000295
#
#                  American Pit Bull Terrier/Chinese Sharpei  \
# OutcomeType
# Adoption                                          0.000201
# Died                                              0.000692
# Euthanasia                                        0.000527
# Return_to_owner                                   0.000448
# Transfer                                          0.000221
#
#                  American Pit Bull Terrier/Labrador Retriever  \
# OutcomeType
# Adoption                                             0.000201
# Died                                                 0.000692
# Euthanasia                                           0.000527
# Return_to_owner                                      0.000560
# Transfer                                             0.000221
#
#                  American Pit Bull Terrier/Pointer  American Shorthair Mix  \
# OutcomeType
# Adoption                                  0.000268                0.000201
# Died                                      0.000692                0.000692
# Euthanasia                                0.000527                0.000702
# Return_to_owner                           0.000336                0.000448
# Transfer                                  0.000221                0.000737
#
#                  American Staffordshire Terrier  \
# OutcomeType
# Adoption                               0.000470
# Died                                   0.000922
# Euthanasia                             0.000702
# Return_to_owner                        0.000336
# Transfer                               0.000664
#
#                  American Staffordshire Terrier Mix  \
# OutcomeType
# Adoption                                   0.002817
# Died                                       0.000692
# Euthanasia                                 0.002107
# Return_to_owner                            0.003697
# Transfer                                   0.001254
#
#                  American Staffordshire Terrier/American Bulldog  \
# OutcomeType
# Adoption                                                0.000201
# Died                                                    0.000692
# Euthanasia                                              0.000527
# Return_to_owner                                         0.000336
# Transfer                                                0.000295
#
#                  American Staffordshire Terrier/French Bulldog  \
# OutcomeType
# Adoption                                              0.000268
# Died                                                  0.000692
# Euthanasia                                            0.000527
# Return_to_owner                                       0.000336
# Transfer                                              0.000221
#
#                  American Staffordshire Terrier/Labrador Retriever  \
# OutcomeType
# Adoption                                                  0.000335
# Died                                                      0.000692
# Euthanasia                                                0.000527
# Return_to_owner                                           0.000336
# Transfer                                                  0.000295
#
#                  American Staffordshire Terrier/Plott Hound  Anatol Shepherd  \
# OutcomeType
# Adoption                                           0.000201         0.000604
# Died                                               0.000692         0.000692
# Euthanasia                                         0.000702         0.000527
# Return_to_owner                                    0.000336         0.000784
# Transfer                                           0.000221         0.000369
#
#                  Anatol Shepherd Mix  Anatol Shepherd/Australian Cattle Dog  \
# OutcomeType
# Adoption                    0.002683                               0.000201
# Died                        0.000922                               0.000692
# Euthanasia                  0.000702                               0.000527
# Return_to_owner             0.001680                               0.000336
# Transfer                    0.002065                               0.000369
#
#                  Anatol Shepherd/Australian Shepherd  \
# OutcomeType
# Adoption                                    0.000201
# Died                                        0.000692
# Euthanasia                                  0.000527
# Return_to_owner                             0.000336
# Transfer                                    0.000295
#
#                  Anatol Shepherd/Border Collie  Anatol Shepherd/Catahoula  \
# OutcomeType
# Adoption                              0.000470                   0.000335
# Died                                  0.000692                   0.000692
# Euthanasia                            0.000527                   0.000527
# Return_to_owner                       0.000336                   0.000336
# Transfer                              0.000221                   0.000221
#
#                  Anatol Shepherd/Collie Rough  \
# OutcomeType
# Adoption                             0.000268
# Died                                 0.000692
# Euthanasia                           0.000527
# Return_to_owner                      0.000336
# Transfer                             0.000221
#
#                  Anatol Shepherd/German Shepherd  \
# OutcomeType
# Adoption                                0.000201
# Died                                    0.000692
# Euthanasia                              0.000527
# Return_to_owner                         0.000336
# Transfer                                0.000295
#
#                  Anatol Shepherd/Great Pyrenees  \
# OutcomeType
# Adoption                               0.000470
# Died                                   0.000692
# Euthanasia                             0.000527
# Return_to_owner                        0.000448
# Transfer                               0.000295
#
#                  Anatol Shepherd/Labrador Retriever  \
# OutcomeType
# Adoption                                   0.000402
# Died                                       0.000692
# Euthanasia                                 0.000527
# Return_to_owner                            0.000336
# Transfer                                   0.000590
#
#                  Anatol Shepherd/Redbone Hound  \
# OutcomeType
# Adoption                              0.000268
# Died                                  0.000692
# Euthanasia                            0.000527
# Return_to_owner                       0.000336
# Transfer                              0.000442
#
#                  Anatol Shepherd/Siberian Husky  Angora Mix  \
# OutcomeType
# Adoption                               0.000201    0.000470
# Died                                   0.000692    0.000692
# Euthanasia                             0.000527    0.000527
# Return_to_owner                        0.000448    0.000448
# Transfer                               0.000221    0.000369
#
#                  Australian Cattle Dog  Australian Cattle Dog Mix  \
# OutcomeType
# Adoption                      0.000872                   0.012073
# Died                          0.000692                   0.000922
# Euthanasia                    0.000878                   0.002985
# Return_to_owner               0.001120                   0.010307
# Transfer                      0.000664                   0.006562
#
#                  Australian Cattle Dog/Akita  \
# OutcomeType
# Adoption                            0.000201
# Died                                0.000692
# Euthanasia                          0.000527
# Return_to_owner                     0.000560
# Transfer                            0.000221
#
#                  Australian Cattle Dog/Alaskan Husky  \
# OutcomeType
# Adoption                                    0.000268
# Died                                        0.000692
# Euthanasia                                  0.000527
# Return_to_owner                             0.000448
# Transfer                                    0.000221
#
#                  Australian Cattle Dog/American Foxhound  \
# OutcomeType
# Adoption                                        0.000201
# Died                                            0.000692
# Euthanasia                                      0.000527
# Return_to_owner                                 0.000336
# Transfer                                        0.000295
#
#                  Australian Cattle Dog/American Staffordshire Terrier  \
# OutcomeType
# Adoption                                                  0.000268
# Died                                                      0.000692
# Euthanasia                                                0.000527
# Return_to_owner                                           0.000336
# Transfer                                                  0.000221
#
#                  Australian Cattle Dog/Anatol Shepherd  \
# OutcomeType
# Adoption                                      0.000268
# Died                                          0.000692
# Euthanasia                                    0.000527
# Return_to_owner                               0.000448
# Transfer                                      0.000221
#
#                  Australian Cattle Dog/Australian Shepherd  \
# OutcomeType
# Adoption                                          0.000335
# Died                                              0.000692
# Euthanasia                                        0.000527
# Return_to_owner                                   0.000336
# Transfer                                          0.000221
#
#                  Australian Cattle Dog/Basenji  Australian Cattle Dog/Beagle  \
# OutcomeType
# Adoption                              0.000268                      0.000402
# Died                                  0.000692                      0.000692
# Euthanasia                            0.000527                      0.000527
# Return_to_owner                       0.000336                      0.000448
# Transfer                              0.000221                      0.000295
#
#                  Australian Cattle Dog/Belgian Malinois  \
# OutcomeType
# Adoption                                       0.000268
# Died                                           0.000692
# Euthanasia                                     0.000527
# Return_to_owner                                0.000336
# Transfer                                       0.000221
#
#                  Australian Cattle Dog/Bloodhound  \
# OutcomeType
# Adoption                                 0.000201
# Died                                     0.000692
# Euthanasia                               0.000527
# Return_to_owner                          0.000560
# Transfer                                 0.000221
#
#                  Australian Cattle Dog/Border Collie  \
# OutcomeType
# Adoption                                    0.000604
# Died                                        0.000692
# Euthanasia                                  0.000702
# Return_to_owner                             0.000672
# Transfer                                    0.000221
#
#                  Australian Cattle Dog/Boxer  \
# OutcomeType
# Adoption                            0.000201
# Died                                0.000692
# Euthanasia                          0.000527
# Return_to_owner                     0.000336
# Transfer                            0.000442
#
#                  Australian Cattle Dog/Bull Terrier  \
# OutcomeType
# Adoption                                   0.000201
# Died                                       0.000692
# Euthanasia                                 0.000527
# Return_to_owner                            0.000336
# Transfer                                   0.000369
#
#                  Australian Cattle Dog/Cardigan Welsh Corgi  \
# OutcomeType
# Adoption                                           0.000402
# Died                                               0.000692
# Euthanasia                                         0.000527
# Return_to_owner                                    0.000336
# Transfer                                           0.000221
#
#                  Australian Cattle Dog/Catahoula  \
# OutcomeType
# Adoption                                0.000268
# Died                                    0.000692
# Euthanasia                              0.000527
# Return_to_owner                         0.000336
# Transfer                                0.000369
#
#                  Australian Cattle Dog/Chinese Sharpei  \
# OutcomeType
# Adoption                                      0.000268
# Died                                          0.000692
# Euthanasia                                    0.000702
# Return_to_owner                               0.000336
# Transfer                                      0.000221
#
#                  Australian Cattle Dog/Chow Chow  \
# OutcomeType
# Adoption                                0.000201
# Died                                    0.000692
# Euthanasia                              0.000527
# Return_to_owner                         0.000560
# Transfer                                0.000295
#
#                  Australian Cattle Dog/Collie Rough  \
# OutcomeType
# Adoption                                   0.000268
# Died                                       0.000692
# Euthanasia                                 0.000527
# Return_to_owner                            0.000336
# Transfer                                   0.000221
#
#                  Australian Cattle Dog/Collie Smooth  \
# OutcomeType
# Adoption                                    0.000201
# Died                                        0.000692
# Euthanasia                                  0.000527
# Return_to_owner                             0.000448
# Transfer                                    0.000221
#
#                  Australian Cattle Dog/Dachshund  \
# OutcomeType
# Adoption                                0.000201
# Died                                    0.000692
# Euthanasia                              0.000527
# Return_to_owner                         0.000448
# Transfer                                0.000221
#
#                  Australian Cattle Dog/Dalmatian  \
# OutcomeType
# Adoption                                0.000201
# Died                                    0.000692
# Euthanasia                              0.000527
# Return_to_owner                         0.000336
# Transfer                                0.000295
#
#                  Australian Cattle Dog/German Shepherd  \
# OutcomeType
# Adoption                                      0.000402
# Died                                          0.000692
# Euthanasia                                    0.000527
# Return_to_owner                               0.000560
# Transfer                                      0.000442
#
#                  Australian Cattle Dog/German Shorthair Pointer  \
# OutcomeType
# Adoption                                               0.000201
# Died                                                   0.000692
# Euthanasia                                             0.000527
# Return_to_owner                                        0.000448
# Transfer                                               0.000221
#
#                  Australian Cattle Dog/Golden Retriever  \
# OutcomeType
# Adoption                                       0.000201
# Died                                           0.000692
# Euthanasia                                     0.000527
# Return_to_owner                                0.000336
# Transfer                                       0.000295
#
#                  Australian Cattle Dog/Great Pyrenees  \
# OutcomeType
# Adoption                                     0.000268
# Died                                         0.000692
# Euthanasia                                   0.000527
# Return_to_owner                              0.000336
# Transfer                                     0.000221
#
#                  Australian Cattle Dog/Jack Russell Terrier  \
# OutcomeType
# Adoption                                           0.000268
# Died                                               0.000692
# Euthanasia                                         0.000527
# Return_to_owner                                    0.000336
# Transfer                                           0.000369
#
#                  Australian Cattle Dog/Labrador Retriever  \
# OutcomeType
# Adoption                                         0.001140
# Died                                             0.000692
# Euthanasia                                       0.000702
# Return_to_owner                                  0.001344
# Transfer                                         0.000737
#
#                  Australian Cattle Dog/Parson Russell Terrier  \
# OutcomeType
# Adoption                                             0.000268
# Died                                                 0.000692
# Euthanasia                                           0.000527
# Return_to_owner                                      0.000336
# Transfer                                             0.000221
#
#                  Australian Cattle Dog/Pembroke Welsh Corgi  \
# OutcomeType
# Adoption                                           0.000268
# Died                                               0.000692
# Euthanasia                                         0.000527
# Return_to_owner                                    0.000336
# Transfer                                           0.000295
#
#                  Australian Cattle Dog/Pit Bull  \
# OutcomeType
# Adoption                               0.000537
# Died                                   0.000692
# Euthanasia                             0.000702
# Return_to_owner                        0.000672
# Transfer                               0.000221
#
#                  Australian Cattle Dog/Plott Hound  \
# OutcomeType
# Adoption                                  0.000268
# Died                                      0.000692
# Euthanasia                                0.000527
# Return_to_owner                           0.000336
# Transfer                                  0.000295
#
#                  Australian Cattle Dog/Pointer  \
# OutcomeType
# Adoption                              0.000470
# Died                                  0.000692
# Euthanasia                            0.000527
# Return_to_owner                       0.000336
# Transfer                              0.000295
#
#                  Australian Cattle Dog/Queensland Heeler  \
# OutcomeType
# Adoption                                        0.000201
# Died                                            0.000692
# Euthanasia                                      0.000527
# Return_to_owner                                 0.000448
# Transfer                                        0.000221
#
#                  Australian Cattle Dog/Rat Terrier  \
# OutcomeType
# Adoption                                  0.000268
# Died                                      0.000692
# Euthanasia                                0.000527
# Return_to_owner                           0.000336
# Transfer                                  0.000221
#
#                  Australian Cattle Dog/Rhod Ridgeback  \
# OutcomeType
# Adoption                                     0.000268
# Died                                         0.000692
# Euthanasia                                   0.000527
# Return_to_owner                              0.000336
# Transfer                                     0.000221
#
#                  Australian Cattle Dog/Staffordshire  Australian Kelpie  \
# OutcomeType
# Adoption                                    0.000268           0.000335
# Died                                        0.000692           0.000692
# Euthanasia                                  0.000527           0.000527
# Return_to_owner                             0.000336           0.000336
# Transfer                                    0.000369           0.000516
#
#                  Australian Kelpie Mix  Australian Kelpie/Alaskan Husky  \
# OutcomeType
# Adoption                      0.003823                         0.000268
# Died                          0.000692                         0.000692
# Euthanasia                    0.001054                         0.000527
# Return_to_owner               0.001680                         0.000336
# Transfer                      0.002138                         0.000221
#
#                  Australian Kelpie/American Pit Bull Terrier  \
# OutcomeType
# Adoption                                            0.000201
# Died                                                0.000692
# Euthanasia                                          0.000527
# Return_to_owner                                     0.000336
# Transfer                                            0.000295
#
#                  Australian Kelpie/Australian Shepherd  \
# OutcomeType
# Adoption                                      0.000268
# Died                                          0.000692
# Euthanasia                                    0.000527
# Return_to_owner                               0.000336
# Transfer                                      0.000295
#
#                  Australian Kelpie/Blue Lacy  \
# OutcomeType
# Adoption                            0.000268
# Died                                0.000692
# Euthanasia                          0.000527
# Return_to_owner                     0.000336
# Transfer                            0.000295
#
#                  Australian Kelpie/Chihuahua Shorthair  \
# OutcomeType
# Adoption                                      0.000268
# Died                                          0.000692
# Euthanasia                                    0.000527
# Return_to_owner                               0.000336
# Transfer                                      0.000221
#
#                  Australian Kelpie/Chinese Sharpei  \
# OutcomeType
# Adoption                                  0.000201
# Died                                      0.000692
# Euthanasia                                0.000527
# Return_to_owner                           0.000336
# Transfer                                  0.000295
#
#                  Australian Kelpie/Finnish Spitz  \
# OutcomeType
# Adoption                                0.000268
# Died                                    0.000692
# Euthanasia                              0.000527
# Return_to_owner                         0.000336
# Transfer                                0.000221
#
#                  Australian Kelpie/Labrador Retriever  \
# OutcomeType
# Adoption                                     0.000201
# Died                                         0.000692
# Euthanasia                                   0.000527
# Return_to_owner                              0.000448
# Transfer                                     0.000221
#
#                  Australian Kelpie/Pit Bull  Australian Kelpie/Shiba Inu  \
# OutcomeType
# Adoption                           0.000201                     0.000268
# Died                               0.000692                     0.000692
# Euthanasia                         0.000527                     0.000527
# Return_to_owner                    0.000560                     0.000336
# Transfer                           0.000295                     0.000221
#
#                  Australian Kelpie/Whippet  Australian Shepherd  \
# OutcomeType
# Adoption                          0.000268             0.000470
# Died                              0.000692             0.000692
# Euthanasia                        0.000527             0.000702
# Return_to_owner                   0.000336             0.001008
# Transfer                          0.000221             0.000442
#
#                  Australian Shepherd Mix  \
# OutcomeType
# Adoption                        0.005098
# Died                            0.000692
# Euthanasia                      0.001756
# Return_to_owner                 0.006050
# Transfer                        0.002581
#
#                  Australian Shepherd/Alaskan Malamute  \
# OutcomeType
# Adoption                                     0.000268
# Died                                         0.000692
# Euthanasia                                   0.000527
# Return_to_owner                              0.000336
# Transfer                                     0.000221
#
#                  Australian Shepherd/Anatol Shepherd  \
# OutcomeType
# Adoption                                    0.000268
# Died                                        0.000692
# Euthanasia                                  0.000527
# Return_to_owner                             0.000336
# Transfer                                    0.000590
#
#                  Australian Shepherd/Australian Cattle Dog  \
# OutcomeType
# Adoption                                          0.000402
# Died                                              0.000692
# Euthanasia                                        0.000702
# Return_to_owner                                   0.000560
# Transfer                                          0.000221
#
#                  Australian Shepherd/Australian Kelpie  \
# OutcomeType
# Adoption                                      0.000268
# Died                                          0.000692
# Euthanasia                                    0.000527
# Return_to_owner                               0.000336
# Transfer                                      0.000221
#
#                  Australian Shepherd/Beagle  \
# OutcomeType
# Adoption                           0.000268
# Died                               0.000692
# Euthanasia                         0.000527
# Return_to_owner                    0.000336
# Transfer                           0.000221
#
#                  Australian Shepherd/Border Collie  Australian Shepherd/Boxer  \
# OutcomeType
# Adoption                                  0.000470                   0.000201
# Died                                      0.000692                   0.000692
# Euthanasia                                0.000527                   0.000527
# Return_to_owner                           0.000448                   0.000336
# Transfer                                  0.000295                   0.000295
#
#                  Australian Shepherd/Chihuahua Shorthair  \
# OutcomeType
# Adoption                                        0.000402
# Died                                            0.000692
# Euthanasia                                      0.000527
# Return_to_owner                                 0.000336
# Transfer                                        0.000221
#
#                  Australian Shepherd/Chow Chow  \
# OutcomeType
# Adoption                              0.000268
# Died                                  0.000692
# Euthanasia                            0.000702
# Return_to_owner                       0.000448
# Transfer                              0.000221
#
#                  Australian Shepherd/Cocker Spaniel  \
# OutcomeType
# Adoption                                   0.000268
# Died                                       0.000692
# Euthanasia                                 0.000527
# Return_to_owner                            0.000448
# Transfer                                   0.000221
#
#                  Australian Shepherd/Dachshund  \
# OutcomeType
# Adoption                              0.000268
# Died                                  0.000692
# Euthanasia                            0.000527
# Return_to_owner                       0.000336
# Transfer                              0.000221
#
#                  Australian Shepherd/English Setter  \
# OutcomeType
# Adoption                                   0.000201
# Died                                       0.000692
# Euthanasia                                 0.000527
# Return_to_owner                            0.000448
# Transfer                                   0.000221
#
#                  Australian Shepherd/English Springer Spaniel  \
# OutcomeType
# Adoption                                             0.000201
# Died                                                 0.000692
# Euthanasia                                           0.000527
# Return_to_owner                                      0.000448
# Transfer                                             0.000221
#
#                  Australian Shepherd/Labrador Retriever  \
# OutcomeType
# Adoption                                       0.000671
# Died                                           0.000692
# Euthanasia                                     0.000527
# Return_to_owner                                0.000448
# Transfer                                       0.000516
#
#                  Australian Shepherd/Nova Scotia Duck Tolling Retriever  \
# OutcomeType
# Adoption                                                  0.000201
# Died                                                      0.000692
# Euthanasia                                                0.000527
# Return_to_owner                                           0.000336
# ...
# OutcomeType
# Adoption         0.011123           0.000337      0.000253       0.000253
# Died             0.004633           0.002317      0.002317       0.002317
# Euthanasia       0.006408           0.001131      0.001131       0.001131
# Return_to_owner  0.003229           0.000510      0.000510       0.000680
# Transfer         0.016730           0.000285      0.000380       0.000285
#
#                  Torbie/White    Tortie  Tortie Point  \
# OutcomeType
# Adoption             0.002865  0.018539      0.001433
# Died                 0.002317  0.004633      0.002317
# Euthanasia           0.001885  0.012062      0.002262
# Return_to_owner      0.001020  0.004589      0.001020
# Transfer             0.002567  0.024715      0.001426
#
#                  Tortie Point/Lynx Point  Tortie Point/White  Tortie/Black  \
# OutcomeType
# Adoption                        0.000253            0.000337      0.000253
# Died                            0.002317            0.002317      0.002317
# Euthanasia                      0.001131            0.001131      0.001131
# Return_to_owner                 0.000510            0.000510      0.000510
# Transfer                        0.000380            0.000285      0.000475
#
#                  Tortie/Black Smoke  Tortie/Blue Cream  Tortie/Brown  \
# OutcomeType
# Adoption                   0.000337           0.000843      0.000253
# Died                       0.002317           0.002317      0.002317
# Euthanasia                 0.001131           0.001131      0.001131
# Return_to_owner            0.000510           0.000680      0.000510
# Transfer                   0.000285           0.000380      0.000380
#
#                  Tortie/Calico  Tortie/Orange  Tortie/White  Tricolor  \
# OutcomeType
# Adoption              0.000253       0.000421      0.001854  0.028314
# Died                  0.002317       0.002317      0.002317  0.002317
# Euthanasia            0.001131       0.001131      0.001508  0.010177
# Return_to_owner       0.000510       0.000510      0.000850  0.033821
# Transfer              0.000380       0.000380      0.001331  0.019202
#
#                  Tricolor/Black  Tricolor/Blue  Tricolor/Blue Merle  \
# OutcomeType
# Adoption               0.000590       0.000337             0.000253
# Died                   0.002317       0.002317             0.002317
# Euthanasia             0.001508       0.001131             0.001131
# Return_to_owner        0.001190       0.000680             0.000680
# Transfer               0.000475       0.000285             0.000285
#
#                  Tricolor/Brown  Tricolor/Brown Merle  Tricolor/Calico  \
# OutcomeType
# Adoption               0.000674              0.000337         0.000253
# Died                   0.002317              0.002317         0.002317
# Euthanasia             0.001131              0.001131         0.001131
# Return_to_owner        0.000680              0.000510         0.000510
# Transfer               0.000380              0.000285         0.000380
#
#                        13        14        15        16        17        18  \
# OutcomeType
# Adoption         0.038759  0.030473  0.030565  0.030289  0.031670  0.042349
# Died             0.017241  0.027586  0.044828  0.048276  0.017241  0.027586
# Euthanasia       0.034587  0.038835  0.038835  0.024272  0.030947  0.025485
# Return_to_owner  0.037508  0.031154  0.030744  0.033613  0.035253  0.029514
# Transfer         0.030058  0.032160  0.031844  0.036679  0.035418  0.035733
#
#                        19        20        21        22        23        24  \
# OutcomeType
# Adoption         0.037746  0.031210  0.033143  0.031394  0.035537  0.031394
# Died             0.024138  0.031034  0.024138  0.031034  0.020690  0.024138
# Euthanasia       0.040049  0.030340  0.033374  0.029126  0.033981  0.036408
# Return_to_owner  0.034843  0.035048  0.032999  0.032384  0.030334  0.032179
# Transfer         0.034472  0.039727  0.035943  0.026905  0.034367  0.031004
#
#                        25        26        27        28        29        30  \
# OutcomeType
# Adoption         0.029276  0.028632  0.032222  0.029368  0.032683  0.035261
# Died             0.034483  0.034483  0.020690  0.058621  0.034483  0.027586
# Euthanasia       0.029126  0.036408  0.032160  0.031553  0.035194  0.029126
# Return_to_owner  0.030744  0.034023  0.031564  0.028489  0.029104  0.029104
# Transfer         0.032685  0.036364  0.031634  0.026905  0.033631  0.032055
#
#                        31     April    August  December  February   January  \
# OutcomeType
# Adoption         0.018321  0.046553  0.088663  0.115965  0.076076  0.096992
# Died             0.024138  0.042918  0.085837  0.055794  0.055794  0.064378
# Euthanasia       0.012136  0.065368  0.071653  0.096166  0.070396  0.075424
# Return_to_owner  0.018036  0.079220  0.062422  0.109083  0.086064  0.105765
# Transfer         0.017131  0.074540  0.083950  0.080461  0.055614  0.069359
#
#                      July      June     March       May  November   October  \
# OutcomeType
# Adoption         0.106802  0.077094  0.053124  0.063767  0.100324  0.102175
# Died             0.137339  0.128755  0.060086  0.090129  0.085837  0.128755
# Euthanasia       0.093023  0.103080  0.069767  0.083595  0.093652  0.109365
# Return_to_owner  0.066363  0.069473  0.070303  0.076732  0.110742  0.098922
# Transfer         0.091668  0.102770  0.050222  0.094735  0.094735  0.117467
#
#                  September     count
# OutcomeType
# Adoption          0.072466  0.402896
# Died              0.064378  0.007370
# Euthanasia        0.068510  0.058177
# Return_to_owner   0.064911  0.179056
# Transfer          0.084479  0.352501
#
# [5 rows x 1807 columns]

# %%
NaiveBayes.predict(['True','Cat','Intact Female','adult'])
# Out:
# {u'Adoption': 0.00023880474979092066,
#  u'Died': 2.8714149395241271e-05,
#  u'Euthanasia': 0.00055942105784742265,
#  u'Return_to_owner': 0.00029227838513970288,
#  u'Transfer': 0.0022114936943828005}

# %%
# Out:
#           ID        Name             DateTime AnimalType SexuponOutcome  \
# 0          1      Summer  2015-10-12 12:15:00        Dog  Intact Female
# 1          2    Cheyenne  2014-07-26 17:59:00        Dog  Spayed
# 11437       6 months          Chihuahua Longhair/Dachshund          White/Tan
# 11438        1 month                Labrador Retriever Mix              Sable
# 11439        2 years                          Pit Bull Mix        White/Brown
# 11440         1 week                Domestic Shorthair Mix        Brown Tabby
# 11441        4 years                          Pit Bull Mix         Blue/White
# 11442        2 years               Chihuahua Shorthair Mix          Tan/White
# 11443       6 months                 Domestic Longhair Mix             Torbie
# 11444        2 years                Domestic Shorthair Mix             Calico
# 11445        2 weeks                Domestic Shorthair Mix              White
# 11446       2 months                Domestic Shorthair Mix              Black
# 11447         1 year                Chihuahua Longhair Mix         Orange/Tan
# 11448       2 months                Labrador Retriever Mix              Brown
# 11449       6 months                    Bearded Collie Mix   Blue Merle/White
# 11450      10 months                     Staffordshire Mix          Tan/White
# 11451       2 months                Domestic Shorthair Mix              Black
# 11452        2 weeks                Domestic Shorthair Mix               Blue
# 11453         1 year                Domestic Shorthair Mix             Calico
# 11454        6 years                   German Shepherd Mix          Black/Tan
# 11455        4 years                    Labrador Retriever              Cream
#
# [11456 rows x 8 columns]

# %%
testing2 = testing.copy()
testing2 = testing2.drop(testing2.index[21])
testing2 = testing2.drop(testing2.index[129])
NaiveBayes.run(testing2)
# Out:
# KeyErrorTraceback (most recent call last)
# <ipython-input-149-dd8c7c523b68> in <module>()
#       2 testing2 = testing2.drop(testing2.index[21])
#       3 testing2 = testing2.drop(testing2.index[130])
# ----> 4 NaiveBayes.run(testing2)
#
# <ipython-input-137-95f634f0ebb5> in run(self, dataframe)
#      84             prediction = max(predictions.iteritems(), key=operator.itemgetter(1))[0]
#      85             return prediction
# ---> 86         dataframe['Prediction'] = dataframe.apply(do_prediction, axis=1)
#      87         return dataframe
#
# /opt/conda/envs/python2/lib/python2.7/site-packages/pandas/core/frame.pyc in apply(self, func, axis, broadcast, raw, reduce, args, **kwds)
#    4150                     if reduce is None:
#    4151                         reduce = True
# -> 4152                     return self._apply_standard(f, axis, reduce=reduce)
#    4153             else:
#    4154                 return self._apply_broadcast(f, axis)
#
# /opt/conda/envs/python2/lib/python2.7/site-packages/pandas/core/frame.pyc in _apply_standard(self, func, axis, ignore_failures, reduce)
#    4246             try:
#    4247                 for i, v in enumerate(series_gen):
# -> 4248                     results[i] = func(v)
#    4249                     keys.append(v.name)
#    4250             except Exception as e:
#
# <ipython-input-137-95f634f0ebb5> in do_prediction(x)
#      81             instance = list(x)
#      82             del instance[-1]
# ---> 83             predictions = self.predict(instance)
#      84             prediction = max(predictions.iteritems(), key=operator.itemgetter(1))[0]
#      85             return prediction
#
# <ipython-input-137-95f634f0ebb5> in predict(self, instance)
#      48         outputs = self.dataframe[self.target_feature].unique()
#      49         for output in outputs:
# ---> 50             predictions[output] = self.target_probability(instance,output)
#      51         return predictions
#      52
#
# <ipython-input-137-95f634f0ebb5> in target_probability(self, instance, target)
#      55         instance_probabilities = []
#      56         for feature in instance:
# ---> 57             probability = self.probabilities[feature][target]
#      58             instance_probabilities.append(probability)
#      59         multiplication = reduce(lambda x, y: x*y, instance_probabilities)
#
# /opt/conda/envs/python2/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    2057             return self._getitem_multilevel(key)
#    2058         else:
# -> 2059             return self._getitem_column(key)
#    2060
#    2061     def _getitem_column(self, key):
#
# /opt/conda/envs/python2/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_column(self, key)
#    2064         # get column
#    2065         if self.columns.is_unique:
# -> 2066             return self._get_item_cache(key)
#    2067
#    2068         # duplicate columns & possible reduce dimensionality
#
# /opt/conda/envs/python2/lib/python2.7/site-packages/pandas/core/generic.pyc in _get_item_cache(self, item)
#    1384         res = cache.get(item)
#    1385         if res is None:
# -> 1386             values = self._data.get(item)
#    1387             res = self._box_item_values(item, values)
#    1388             cache[item] = res
#
# /opt/conda/envs/python2/lib/python2.7/site-packages/pandas/core/internals.pyc in get(self, item, fastpath)
#    3541
#    3542             if not isnull(item):
# -> 3543                 loc = self.items.get_loc(item)
#    3544             else:
#    3545                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# /opt/conda/envs/python2/lib/python2.7/site-packages/pandas/indexes/base.pyc in get_loc(self, key, method, tolerance)
#    2134                 return self._engine.get_loc(key)
#    2135             except KeyError:
# -> 2136                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2137
#    2138         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4433)()
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4279)()
#
# pandas/src/hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:13742)()
#
# pandas/src/hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:13696)()
#
# KeyError: (u'Chinese Sharpei/Airedale Terrier', u'occurred at index 129')

# %% [markdown]
# # KNN

# %%
import operator

def jaccardSimilarity(row1, row2):
    similarity = 0
    for i in range (len(row1)):
        #print(row1[i])
        #print(row2[i])
        if row1[i] == row2[i]:
            similarity += 1
    return float(similarity)/len(row1)

def getNeighbours(k, query, dataset):     ## Returns a list of the k nearest neighbour(s) of the query
    datasetWithoutTarget = dataset.drop("OutcomeType", 1)
    datasetWithoutTarget = datasetWithoutTarget.reset_index(drop=True)
    dictDistance = {}
    for i in range(len(datasetWithoutTarget)):
        dictDistance[i] = jaccardSimilarity(query, datasetWithoutTarget.ix[i])
    sorted_dictDistance = sorted(dictDistance.items(), key=operator.itemgetter(1))
    k_sorted_dictDistance = []
    for i in sorted_dictDistance[-k:]:
        k_sorted_dictDistance.append(i[0])
    return k_sorted_dictDistance


def KNN(neighbours, dataset):
    dictOutcome = {}
    for i in neighbours:
        if dataset.ix[i][0] in dictOutcome:
            dictOutcome[dataset.ix[i][0]] += 1
        else:
            dictOutcome[dataset.ix[i][0]] = 1
    sortedOutcomes = sorted(dictOutcome.iteritems(), key=operator.itemgetter(1), reverse=True)
    return sortedOutcomes[0][0]

## PS: Here, everything takes as an argument the dataset WITH the target feature
## The dataset must have the target feature (OutcomeType) as first column
## To make a KNN prediction for a query given a dataset --> KNN(getNeighbours(k, query, dataset), dataset)

# %%
iasf = testing.toPandas()
for i in range(0, len(iasf)):
    print(KNN(getNeighbours(10, iasf.ix[i], shelter_cleaned_df), shelter_cleaned_df))

# %%
cats = shelter_pd.loc[shelter_pd['AnimalType'] == 'Cat']
pd.DataFrame(cats['SexuponOutcome'].value_counts()).plot(kind='bar')

# %%
dogs= shelter_pd.loc[shelter_pd['AnimalType'] == 'Dog']
pd.DataFrame(dogs['SexuponOutcome'].value_counts()).plot(kind='bar')

# %%
not_missing_values_pd = shelter_pd.loc[(shelter_pd['SexuponOutcome'] != 'Unknown') & (shelter_pd['SexuponOutcome'] != 'NaN')]
# me aseguro de haber tomado todos los datos correctos
not_missing_values_pd.describe()

# %% [markdown]
# ##### Como se puede ver no hay missing values para SexuponOutcome. Acontinuacion lo demostrara un grafico.

# %%
pd.DataFrame(not_missing_values_pd['SexuponOutcome'].value_counts()).plot(kind='bar')

# %% [markdown]
# ##### Acontinuacion, se dividra este dataframe en dos 70% para entrenamiento y 30% para testing

# %%
training = not_missing_values_pd.sample(frac=0.7, replace=False)
testing = not_missing_values_pd.drop(training.index)

# %%
print(getMode(shelter_df, "SexuponOutcome"))

# %%
shelter_pd = missingValuesRemover(shelter_pd, "AgeuponOutcome")
shelter_pd = missingValuesRemover(shelter_pd, "SexuponOutcome")
del shelter_pd['AnimalID']
del shelter_pd['OutcomeSubtype']
del shelter_pd['Name']

# %% [markdown]
# ### Part II: Indexation

# %%
shelter_pd[['DateTime', 'OutcomeType', 'AnimalType', 'SexuponOutcome', 'AgeuponOutcome', 'Breed', 'Color']] = shelter_pd[['DateTime', 'OutcomeType', 'AnimalType', 'SexuponOutcome', 'AgeuponOutcome', 'Breed', 'Color']].astype(str)
shelter_df = sqlContext.createDataFrame(shelter_pd)

## Creating a Spark Dataframe from the Pandas Dataframe in order to use it with the Decision Tree model.

# %%
# from pyspark.sql.functions import UserDefinedFunction
# from pyspark.sql.types import IntegerType, LongType, StringType


# class AgeuponOutcomeTransformer(Transformer, HasInputCol, HasOutputCol): 
#     # Does binning using the module of the division
#     @keyword_only
#     def __init__(self, inputCol=None, outputCol=None):
#         super(AgeuponOutcomeTransformer, self).__init__()
#         kwargs = self.__init__._input_kwargs
#         self.setParams(**kwargs)
        
#     @keyword_only 
#     def setParams(self, inputCol=None, outputCol=None):
#         kwargs = self.setParams._input_kwargs
#         return self._set(**kwargs)
        
#     def _transform(self, dataset):
#         in_col = dataset[self.getInputCol()]
#         out_col = self.getOutputCol()
#         udf = UserDefinedFunction(lambda x: category_func(x), StringType())
#         return dataset.withColumn(out_col, udf(in_col))

# def category_func(in_value):
#     if (in_value):
#         age_in_days = 0
#         splited_value = in_value.split(' ')        
#         if (splited_value[1] == 'years' or splited_value[1] == 'year'):
#             age_in_days = int(splited_value[0])*365
#         elif(splited_value[1] == 'months' or splited_value[1] == 'month'):
#             age_in_days = int(splited_value[0])*30
#         elif(splited_value[1] == 'weeks' or splited_value[1] == 'week'):
#             age_in_days = int(splited_value[0])*7
                
#         if (age_in_days > 0 and age_in_days <= 365):
#             return 'young'
#         elif (age_in_days > 365 and age_in_days <= 365*3):
#             return 'young_adult'
#         elif (age_in_days > 365*3 and age_in_days <= 365*7):
#             return 'adult'
#         elif (age_in_days > 365*7 and age_in_days <= 365*10):
#             return 'old_adult'
#         elif (age_in_days > 365*10):
#             return 'old'
#     else:
#         return 'None'

# %%
class BinningTransformer(Transformer, HasInputCol, HasOutputCol): 
    # Does binning using the module of the division
    @keyword_only
    def __init__(self, inputCol=None, outputCol=None):
        super(BinningTransformer, self).__init__()
        kwargs = self.__init__._input_kwargs
        self.setParams(**kwargs)
        
    @keyword_only 
    def setParams(self, inputCol=None, outputCol=None):
        kwargs = self.setParams._input_kwargs
        return self._set(**kwargs)
        
    def _transform(self, dataset):
        in_col = dataset[self.getInputCol()]
        out_col = self.getOutputCol()
        udf = UserDefinedFunction(lambda x: bin_func(x), DoubleType())
        return dataset.withColumn(out_col, udf(in_col))

def bin_func(in_value):
    if (in_value):
        age_in_days = 0
        splited_value = in_value.split(' ')        
        if (splited_value[1] == 'years' or splited_value[1] == 'year'):
            age_in_days = int(splited_value[0])*365
        elif(splited_value[1] == 'months' or splited_value[1] == 'month'):
            age_in_days = int(splited_value[0])*30
        elif(splited_value[1] == 'weeks' or splited_value[1] == 'week'):
            age_in_days = int(splited_value[0])*7
                
        if (age_in_days > 0 and age_in_days <= 365):
            return 1.0
        elif (age_in_days > 365 and age_in_days <= 365*3):
            return 2.0
        elif (age_in_days > 365*3 and age_in_days <= 365*7):
            return 3.0
        elif (age_in_days > 365*7 and age_in_days <= 365*10):
            return 4.0
        elif (age_in_days > 365*10):
            return 5.0
    else:
        return 0.0

# %%
## Here are all the indexers we're gonna use in the pipeline:
#OutcomeType_indexer = StringIndexer(inputCol="OutcomeType", outputCol="OutcomeType_idx")
#AnimalType_indexer = StringIndexer(inputCol="AnimalType", outputCol="AnimalType_idx")
#SexuponOutcome_indexer = StringIndexer(inputCol="SexuponOutcome", outputCol="SexuponOutcome_idx")
#Breed_indexer = StringIndexer(inputCol="Breed", outputCol="Breed_idx")
#Color_indexer = StringIndexer(inputCol="Color", outputCol="Color_idx")
#Age_indexer = StringIndexer(inputCol='AgeuponOutcome', outputCol='AgeuponOutcome_idx')
#Bin_transformer = BinningTransformer(inputCol='AgeuponOutcome', outputCol='AgeuponOutcome_binned')
#AgeuponOutcome_transformer = AgeuponOutcomeTransformer(inputCol='AgeuponOutcome', outputCol='AgeuponOutcome_category')

Name_transformer = NameTransformer(inputCol='Name', outputCol='Name')
DateTime_YearExtractor = YearExtractor(inputCol='DateTime', outputCol='Year')
DateTime_MonthExtractor = MonthExtractor(inputCol='DateTime', outputCol='Month')
DateTime_DayExtractor = DayExtractor(inputCol='DateTime', outputCol='Day')
SexuponOutcome_transformer = FillMissingValues(inputCol='SexuponOutcome', outputCol='SexuponOutcome')

## Should we use OneHotEncoder or StringIndexer for continuous features?
## It looks like we're using StringIndexer more for stuff like boolean values and
## OneHotEncoder for actual categorical features.. But not sure
## Anyway if it's actally OneHotEncoder that we need to use, we just need to add
## One OneHotIndexer and use the OutcomeType_idx we just created as inputCol..

# %%
#pipeline = Pipeline(stages=[OutcomeType_indexer, AnimalType_indexer, SexuponOutcome_indexer, Breed_indexer, Color_indexer, AgeuponOutcome_transformer, Bin_transformer, DateTime_YearExtractor, DateTime_MonthExtractor, DateTime_DayExtractor])
shelter_pd = shelter_pd[['Name', 'DateTime', 'OutcomeType', 'AnimalType', 'SexuponOutcome', 'AgeuponOutcome', 'Breed', 'Color']].astype(str)
shelter_df = sqlContext.createDataFrame(shelter_pd)
pipeline = Pipeline(stages=[Name_transformer, DateTime_DayExtractor, DateTime_MonthExtractor, DateTime_YearExtractor, SexuponOutcome_transformer])
model = pipeline.fit(shelter_df)
shelter_cleaned_df = model.transform(shelter_df)

# %%
#shelter_df_idx = model.transform(shelter_df)
#shelter_df_idx.show()

# %%
shelter_df_only_idx = shelter_df_idx
shelter_df_only_idx = shelter_df_only_idx.drop('OutcomeType', 'AnimalType', 'SexuponOutcome', 'Breed', 'Color')

## Dropping the tables that are still categorical because they're no use to us.

# %%
shelter_df_only_idx.registerTempTable("shelter")
sqlContext.sql("SELECT OutcomeType_idx, AnimalType_idx, SexuponOutcome_idx, Breed_idx, Color_idx, AgeuponOutcome_binned FROM shelter").show()

## Showing all the indexed tables

# %% [markdown]
# #################################
# #################################
#
#
# OKAY GUYS,
#
# Tenemos que cambiar la columna fecha y edad para poder usarlo con decision tree
#
#
# #################################
# #################################

# %% [markdown]
# ### Para realizar naive base convertimos el cleaned dataframe de spark a pandas

# %%
shelter_df_only_category = shelter_df_idx
shelter_df_only_category = shelter_df_only_category.drop('DateTime', 'OutcomeType_idx', 'AnimalType_idx', 'SexuponOutcome_idx', 'Breed_idx', 'Color_idx','AgeuponOutcome_binned', 'Ageuponoutcome')
shelter_cleaned_df = shelter_df_only_category.toPandas()
shelter_cleaned_df

# %%
shelter_cleaned_df.loc[shelter_cleaned_df['AnimalType'] == 'Cat']

# %%
cats = shelter_cleaned_df.loc[shelter_cleaned_df['AnimalType'] == 'Cat']
cats.describe()
#cats.loc[cats['SexuponOutcome'] == 'Neutered Male'].describe()

# %%
pd.DataFrame(cats['SexuponOutcome'].value_counts()).plot(kind='bar')

# %%
dog = shelter_cleaned_df.loc[shelter_cleaned_df['AnimalType'] == 'Dog']
dog.describe()

# %%
pd.DataFrame(dog['SexuponOutcome'].value_counts()).plot(kind='bar')

# %%
shelter_df["Name"]
